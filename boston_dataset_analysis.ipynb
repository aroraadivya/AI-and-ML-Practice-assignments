# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('boston.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.isnull().any
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.any of       crim     zn  indus   chas    nox     rm    age    dis    rad    tax  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501  False  False  False  False  False  False  False  False  False  False
# 502  False  False  False  False  False  False  False  False  False  False
# 503  False  False  False  False  False  False  False  False  False  False
# 504  False  False  False  False  False  False  False  False  False  False
# 505  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
#crime plotting
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(20,8))
ax[0].scatter(df['crim'],df['medv'],marker='1')
ax[0].set_xlabel('crime plotting')
ax[0].set_ylabel('price plotting')
ax[0].set_title('crime and price')
ax[1].hist(df['crim'],color='red')
ax[1].set_xlabel('crime')
plt.show()

# %%
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(20,8))
ax[0].scatter(df['crim'],df['medv'],marker='1')
ax[0].set_xlabel('crime plotting')
ax[0].set_ylabel('price plotting')
ax[0].set_title('crime and price')
ax[0].axis([0,10,0,60])
ax[1].hist(df['crim'],color='red',bins=100)
ax[1].set_xlabel('crime')
ax[0].axis([0,10,0,350])
plt.show()

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
df['zn'].value_counts()
# Out:
# zn
# 0.0      372
# 20.0      21
# 80.0      15
# 22.0      10
# 12.5      10
# 25.0      10
# 40.0       7
# 45.0       6
# 30.0       6
# 90.0       5
# 95.0       4
# 60.0       4
# 21.0       4
# 33.0       4
# 55.0       3
# 70.0       3
# 34.0       3
# 52.5       3
# 35.0       3
# 28.0       3
# 75.0       3
# 82.5       2
# 85.0       2
# 17.5       1
# 100.0      1
# 18.0       1
# Name: count, dtype: int64

# %%
values=['zero','non-zero']
frequencies=[df[df['zn']==0]['medv'].mean(),
             df[df['zn']!=0]['medv'].mean()]
print(frequencies)
# Out:
# [20.473387096774193, 28.25]

# %%
sns.barplot(x=values,y=frequencies)
plt.xlabel('Residence area zone bar plot')
plt.ylabel('frequency')
plt.show()

# %%
#industy plotting
plt.scatter(df['indus'],df['medv'],color='gray',marker='1')
plt.xlabel('Industry Platting')
plt.ylabel('Medv')
plt.show()

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
df['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
values=['zero','one']
frequencies=[df[df['chas']==0].shape[0],
             df[df['chas']==1].shape[0]]
print(frequencies)
# Out:
# [471, 35]

# %%
fig=plt.figure(figsize=(20,4))
fig.add_subplot(1,2,1)
plt.pie(frequencies,labels=values,
        colors=['orange','gray'],explode=(0.5,0),
        counterclock=False,shadow=True,
        autopct='%1.2f%%')
plt.show()

# %%
fig=plt.figure(figsize=(20,4))
fig.add_subplot(1,2,1)
plt.pie(frequencies,labels=values,
        colors=['orange','gray'],explode=(0.5,0),
        counterclock=False,shadow=True,
        autopct='%1.2f%%')
fig.add_subplot(1,2,2)
sns.countplot(x=df['chas'],data=df)
plt.show()

# %%
plt.scatter(df['nox'],df['medv'],marker='*',color='red')
plt.xlabel('NOX')
plt.ylabel('MEDV')
plt.title('NOX vs MEDV')
plt.show()

# %%
fig=plt.figure(figsize=(20,8))
fig.add_subplot(1,2,1)
plt.scatter(df['rm'],df['medv'],marker='<',color='green')
plt.title('RM vs MEDV')
# Out:
# Text(0.5, 1.0, 'RM vs MEDV')

# %%
fig=plt.figure(figsize=(20,8))
fig.add_subplot(1,2,1)
plt.scatter(df['rm'],df['medv'],marker='<',color='green')
plt.title('RM vs MEDV')
fig.add_subplot(1,2,2)
sns.boxplot(y=df['rm'],color='red')
plt.title('RM boxplot')
plt.show()

# %%
sns.relplot(x='age',y='medv',data=df)
# Out:
# c:\Users\divya\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.scatter(df['dis'],df['medv'],color='orange',marker='.')
plt.xlabel('DIS')
plt.ylabel('MEDV')
plt.title('DIS vs MEDV')
plt.show()

# %%
plt.scatter(df['rad'],df['medv'],color='grey',marker='o')
plt.xlabel('RAD')
plt.ylabel('MEDV')
plt.title('RAD vs MEDV')
plt.show()

# %%
plt.scatter(df['tax'],df['medv'],color='lightgreen',marker='.')
plt.xlabel('TAX')
plt.ylabel('MEDV')
plt.title('TAX vs MEDV')
plt.show()

# %%
plt.scatter(df['ptratio'],df['medv'],color='hotpink',marker='o')
plt.xlabel('PTRATIO')
plt.ylabel('MEDV')
plt.title('PTRATIO vs MEDV')
plt.show()

# %%
fig=plt.figure(figsize=(20,8))
fig.add_subplot(1,2,1)
plt.scatter(df['b'],df['medv'],color='blue',marker='o')

# %%
fig=plt.figure(figsize=(20,8))
fig.add_subplot(1,2,1)
plt.scatter(df['b'],df['medv'],color='blue',marker='o')

fig.add_subplot(1,2,2)
sns.boxplot(y=df['b'],color='red')
# Out:
# <Axes: ylabel='b'>

# %%
fig=plt.figure(figsize=(20,8))
fig.add_subplot(1,2,1)
plt.scatter(df['b'],df['medv'],color='blue',marker='o')

fig.add_subplot(1,2,2)
sns.boxplot(y=df['b'],color='red')
plt.title('box plotting of B')
# Out:
# Text(0.5, 1.0, 'box plotting of B')

# %%
plt.scatter(df['lstat'],df['medv'],marker='<',color='red')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
rows=2
cols=7
fif,ax=plt.subplots(nrows=rows,ncols=cols,figsize=(16,4))
col=df.columns
index=0
for i in range(rows):
    for j in range(cols):
        sns.distplot(df[col[index]],ax=ax[i][j],color='green')
        index=index+1
plt.tight_layout()

# %%
cormat=df.corr()
cormat
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
fig=plt.figure(figsize=(12,8))
fig.add_subplot(1,1,1)
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
fig=plt.figure(figsize=(12,8))
fig.add_subplot(1,1,1)
sns.heatmap(df.corr(),annot=True,annot_kws={'size':12})
# Out:
# <Axes: >

# %%
def getcorreleatedfeatures(corrdata,threshold):
    feature=[]
    value=[]
    for i,index in enumerate(corrdata.index):
        if abs(corrdata[index])>threshold:
            feature.append(index)
            value.append(corrdata[index])
            df=pd.DataFrame(data=value,index=feature,columns=['corr_values'])
    return df

# %%
threshold=0.50
corr_value=getcorreleatedfeatures(cormat['medv'],threshold)
corr_value
# Out:
#          corr_values
# rm          0.695360
# ptratio    -0.507787
# lstat      -0.737663
# medv        1.000000

# %%
correlated_data=df[corr_value.index]
correlated_data.head()
# Out:
#       rm  ptratio  lstat  medv
# 0  6.575     15.3   4.98  24.0
# 1  6.421     17.8   9.14  21.6
# 2  7.185     17.8   4.03  34.7
# 3  6.998     18.7   2.94  33.4
# 4  7.147     18.7   5.33  36.2

# %%
sns.pairplot(correlated_data)
plt.show()

# %%
sns.heatmap(correlated_data.corr(),annot=True,annot_kws={'size':12})
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split

# %%
x=correlated_data.drop(labels=['medv'],axis=1)
y=correlated_data['medv']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((404, 3), (102, 3), (404,), (102,))

# %%
from sklearn.linear_model import LinearRegression

# %%
model =LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
df=pd.DataFrame(data=[y_pred,y_test])
df.T.head()
# Out:
#            0     1
# 0  26.718396  23.6
# 1  30.663291  32.4
# 2  16.426377  13.6
# 3  24.728708  22.8
# 4  18.342368  16.1

# %%
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
score=r2_score(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
print(score)
print(mae)
print(mse)
# Out:
# 0.6302528487272827
# 3.3325380783240974
# 27.11495741558058

# %%
import pickle

# %%
with open('boston_model','wb')as f:
    pickle.dump(model,f)
